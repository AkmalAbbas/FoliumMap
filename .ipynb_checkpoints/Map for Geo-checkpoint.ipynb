# %%
help(folium)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-61bff5cef0bf> in <module>
# ----> 1 help(folium)
#
# NameError: name 'folium' is not defined

# %%
import folium
from folium import FeatureGroup

# %%
m = folium.Map(
    [38.58,-99.09],
    tiles='Stamen Terrain',
    zoom_start=6)
fg = FeatureGroup(name='Some icons')

# %%
import pandas

# %%
volcanoes = pandas.read_csv('3.1 Volcanoes.txt')

# %%
lat,lon = list(volcanoes['LAT']),list(volcanoes['LON'])

# %%
elev = list(volcanoes['ELEV'])
name = list(volcanoes['NAME'])
print(name)
# Out:
# ['Baker', 'Glacier Peak', 'Rainier', 'St. Helens', 'Adams', 'West Crater', 'Indian Heaven', 'Hood', 'Jefferson', 'Blue Lake Crater', 'Sand Mountain Field', 'Washington', 'Belknap', 'North Sister Field', 'South Sister', 'Bachelor', 'Newberry Volcano', 'Davis Lake', 'Devils Garden', 'Cinnamon Butte', 'Squaw Ridge Lava Field', 'Four Craters Lava Field', 'Crater Lake', 'Yellowstone', 'Diamond Craters', 'Jordan Craters', 'Saddle Butte', 'Craters of the Moon', 'Hell Half Acre', 'Shoshone Lava Field', 'Jackies Butte', 'Medicine Lake', 'Wapi Lava Field', 'Shasta', 'Brushy Butte', 'Big Cave', 'Twin Buttes', 'Tumble Buttes', 'Eagle Lake Field', 'Lassen Volc Center', 'Clear Lake', 'Steamboat Springs', 'Dotsero', 'Mono Lake Volc Field', 'Black Rock Desert', 'Mono Craters', 'Inyo Craters', 'Long Valley', 'Red Cones', 'Ubehebe Craters', 'Markagunt Plateau', 'Santa Clara', 'Bald Knoll', 'Golden Trout Creek', 'Coso Volc Field', 'Uinkaret Field', 'Lavic Lake', 'Valles Caldera', 'Sunset Crater', 'Amboy', 'Zuni-Bandera', 'Carrizozo']

# %%
html = """<h4>Volcano information:</h4>
Height: %s m<br>
Name: %s
"""

fg = FeatureGroup(name='Some icons')

def color_of_volcanoes(elevation):
    if elevation < 1000:
        return 'green'
    elif 1000 <= elevation < 3000:
        return 'orange'
    else:
        return 'red'
    
fg.add_child(folium.GeoJson(data=(open('world.json').read())))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-42-ee39edcf93ca> in <module>
#      14         return 'red'
#      15
# ---> 16 fg.add_child(folium.GeoJson(data=(open('world.json','r',encoding='utf-8-sig').read())))
#
# ~\Anaconda3\lib\site-packages\folium\features.py in __init__(self, data, style_function, highlight_function, name, overlay, control, show, smooth_factor, tooltip, embed)
#     448         self.highlight = highlight_function is not None
#     449
# --> 450         self.data = self.process_data(data)
#     451
#     452         if self.style or self.highlight:
#
# ~\Anaconda3\lib\site-packages\folium\features.py in process_data(self, data)
#     479             elif data.lstrip()[0] in '[{':  # This is a GeoJSON inline string
#     480                 self.embed = True
# --> 481                 return json.loads(data)
#     482             else:  # This is a filename
#     483                 if not self.embed:
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     338         end = _w(s, end).end()
#     339         if end != len(s):
# --> 340             raise JSONDecodeError("Extra data", s, end)
#     341         return obj
#     342
#
# JSONDecodeError: Extra data: line 1 column 2108737 (char 2108736)

# %%
for lt,ln,el,nm in zip(lat,lon,elev,name):
    iframe = folium.IFrame(html=html % (el,nm), width=200, height=100)
    fg.add_child(folium.CircleMarker(location=[lt,ln],radius = 6,
                                     popup=folium.Popup(iframe),
                                     fill_color = color_of_volcanoes(el),color='grey',fill_opacity=0.7))

# %%
m.add_child(fg)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
